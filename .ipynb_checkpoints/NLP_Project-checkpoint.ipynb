# %%
import json
import pandas as pd
import requests
from io import StringIO

def download_dataset(task, dataset_type="raw"):
    """
        Inputs:
            - task (string): Task name (either "social-acceptability" or "toxicity")
        Outputs:
            - Downloads the dataset corresponding to the task name from the LabintheWild API.
    """
    url = "https://{}-litw.apps.allenai.org/api/v1/dataset?type={}".format(
        task if task == TOXICITY else "delphi",
        dataset_type)
    response = requests.get(url)

    df = pd.read_csv(StringIO(response.text), sep=",")
    df.to_csv('./nlpositionality_{}_{}.csv'.format(task, dataset_type), index=False)

def process_litw_data(old_df):
    """
        Inputs:
            - old_df (DataFrame): Joined dataset with raw demographic values, LabintheWild and dataset annotations, and model predictions
        Outputs:
            - df (DataFrame): Joined dataset with processed demographic values for analysis
    """
    df = old_df.copy()
    df['age'] = df['age'].apply(__process_age__)
    df['gender'] = df['gender'].apply(__process_gender__)
    df['ethnicity'] = df['ethnicity'].apply(__process_ethnicities__)
    df['religion'] = df['religion'].apply(__process_religion__)
    df['education'] = df['education'].apply(__process_education__)
    df['native_language'] = df['native_language'].apply(lambda x: __filter_language_english__(__process_language__(x)))
    df['country_longest'] = df['country_longest'].apply(lambda x: __filter_country_sphere__(__process_country__(x)))
    df['country_residence'] = df['country_residence'].apply(lambda x: __filter_country_sphere__(__process_country__(x)))

    return df

def __process_age__(val):
    """
        Inputs:
            - val (int): age value to be processed
        Outputs:
            - (string): age group the value belongs to; "None" if the value is null
    """
    if pd.isnull(val):
        return 'None'
    if val >= 10 and val < 20:
        return '10-20'
    if val >= 20 and val < 30:
        return '20-30'
    if val >= 30 and val < 40:
        return '30-40'
    if val >= 40 and val < 50:
        return '40-50'
    if val >= 50 and val < 60:
        return '50-60'
    if val >= 60 and val < 70:
        return '60-70'
    if val >= 70 and val < 80:
        return '70-80'
    if val >= 80:
        return '> 80'
    return 'None'

def __process_gender__(val):
    """
        Inputs:
            - val (string): gender value to be processed
        Outputs:
            - (string): gender category the value belongs to ("man", "woman", "non-binary"); "None" if the value is null or not in one of the three categories
    """

    if val == 'man':
        return 'man'
    if val == 'woman':
        return 'woman'
    if val == 'non-binary':
        return 'non-binary'

    #removing nans before string operations
    if pd.isnull(val):
        return 'None'

    #we group them in non-binary for now
    if 'agender' in val.lower():
        return 'non-binary'
    if 'genderfluid' in val.lower():
        return 'non-binary'

    #otherwise none, includes random fillings and no response
    return 'None'

def __process_ethnicities__(val):
    """
        Inputs:
            - val (string): ethnicity value to be processed
        Outputs:
            - (string): ethnicity category the value belongs to; "None" if the value is null or not in one of the predefined categories
    """
    stored = ['white', 'asian, asian american', 'pacific islander, native australian', 'black, african american', 'latino/latina, hispanic', 'mixed', 'Arab-american', 'native american, american indian, alaska native']
    if val in stored:
        return val.split(',')[0].lower()
    return "None"

def __process_religion__(val):
    """
        Inputs:
            - val (string): religion value to be processed
        Outputs:
            - (string): religion category the value belongs to; "None" if the value is null or not in one of the predefined categories
    """

    if pd.isnull(val):
        return 'None'

    if val.lower() in ["roman catholic", "protestant", "orthodox", "christian", "baptist"] or "christian" in val.lower():
        return "christian"

    if val.lower() in ["agnostic theist", "spiritual", "paganism"]:
        return "spiritual"

    if val.lower() in ["hindu", "buddhist", "muslim", "jew"]:
        return val
    return "None"

def __process_education__(val):
    """
        Inputs:
            - val (string): education value to be processed
        Outputs:
            - (string): education category the value belongs to; "None" if the value is null or not in one of the predefined categories
    """
    if pd.isnull(val):
        return 'None'

    stored = ["college", "high school", "graduate school", "phd", "professional school", "pre-high school"]

    if val.lower() in stored:
        return val

    return "None"

def __process_language__(val):
    """
        Inputs:
            - val (string): language value to be processed
        Outputs:
            - (string): language value if it is not null; "None" if the value is null
    """
    if pd.isnull(val):
        return 'None'
    return val

def __filter_language_english__(val):
    """
        Inputs:
            - val (string): language value to be processed
        Outputs:
            - (string): language category the value belongs to ("english", "not english"); "None" if the value is null or not in one of the predefined categories
    """
    if val == 'None':
        return val

    if val == 'English':
        return 'english'

    return 'not english'

def __process_country__(val):
    """
        Inputs:
            - val (string): country value to be processed
        Outputs:
            - (string): country value if it is not null; "None" if the value is null
    """
    if pd.isnull(val):
        return 'None'
    return val

def __filter_country_sphere__(val):
    """
        Inputs:
            - val (string): country value to be processed
        Outputs:
            - (string): country category the value belongs to based on cultural spheres; "None" if the value is null or not in one of the predefined categories
    """
    spheres = json.load(open('./spheres.json'))
    if val not in spheres:
        return 'None'
    return spheres[val]

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # Supress pandas warnings
from scipy import stats
from statsmodels.stats.multitest import multipletests

SOCIAL_ACCEPTABILITY = "social-acceptability"
TOXICITY = "toxicity"

SOCIAL_CHEM = "socialchem"
DELPHI = "delphi"
GPT4 = "gpt4"
DYNAHATE = "dynahate"
HATEROBERTA = "hateroberta"
PERSPECTIVE_API = "perspective"
REWIRE = "rewire"

def get_pearson_rs(task, model_or_dataset_name, dataset_type="raw"):
    """
        Inputs:
            - task (string): Task name (either "social acceptability" or "toxicity")
            - model_or_dataset_name (string): Name of a model or dataset (either "socialchem", "delphi", "gpt4", "dynahate",
              "hateroberta", "perspective", or "rewire")
        Outputs:
            - pearson_rs (DataFrame): DataFrame representing the Pearson's r coefficients and p-values between the dataset
              labels/model scores and LabintheWild volunteer annotations by demographic.

    """
    is_valid_social_acceptability = task == SOCIAL_ACCEPTABILITY and model_or_dataset_name in [SOCIAL_CHEM, DELPHI, GPT4]
    is_valid_toxicity = task == TOXICITY and model_or_dataset_name in [GPT4, DYNAHATE, HATEROBERTA, PERSPECTIVE_API, REWIRE]

    # Processed dataset is already downloaded via the API
    if dataset_type == "processed" and (is_valid_toxicity or is_valid_social_acceptability):
        df = pd.read_csv('nlpositionality_{}_processed.csv'.format(task))
    elif dataset_type == "raw" and (is_valid_toxicity or is_valid_social_acceptability):
        df = pd.read_csv('nlpositionality_{}_raw.csv'.format(task))
        df = process_litw_data(df)
    else:
        raise ValueError('Invalid task name or model or dataset name')

    results = {}
    pvalues = []
    for c in ['country_longest', 'education', 'ethnicity', 'gender', 'native_language', 'age', 'country_residence', 'religion']:
        demo = list(df[c].unique()) # Get all the demographics under a category
        demo.sort()

        if 'None' in demo:
            demo.remove('None')

        if 'mixed' in demo:
            demo.remove('mixed')

        if 'arab-american' in demo:
            demo.remove('arab-american')

        for d in demo:
            ndf = df[df[c] == d] # Get all the instances from a demographic group
            dndf = __mean_df__(ndf, model_or_dataset_name) # Average responses in a demographic group
            r, p = stats.pearsonr(dndf['litw'], dndf[model_or_dataset_name]) # Compute Pearson R values

            results[c + '_' + d] = r
            pvalues.append(p)

    assert(len(results) == len(pvalues))

    # Apply Berforroni stepwise correction
    alpha = 0.001
    hypotheses, pvalues, _, new_alpha = multipletests(pvalues, alpha, method='bonferroni', is_sorted=False, returnsorted=False)

    data = []
    for key, p, h in zip(results.keys(), pvalues, hypotheses):
        # Convert p-values and Pearson's rs to strings
        p = str(p)

        value = str(round(results[key], 2))
        if len(value) == 3:
            value += "0"
        value = value + '' + ('*' if h == True else '')

        data.append({
            "demographic": key,
            "pearson's r": value,
            "p-value": p
        })

    pearson_rs = pd.DataFrame(data=data) # Convert the data to a DataFrame
    return pearson_rs

def __mean_df__(df, model_or_dataset_name):
    ddf = df.groupby(['action']).mean()[['litw', model_or_dataset_name]].reset_index()
    ddf['litw'] = ddf['litw'].apply(lambda x: round(x))
    return ddf

# %%
experiments = [
    (SOCIAL_ACCEPTABILITY, SOCIAL_CHEM),
    (SOCIAL_ACCEPTABILITY, DELPHI),
    (SOCIAL_ACCEPTABILITY, GPT4),
    (TOXICITY, DYNAHATE),
    (TOXICITY, PERSPECTIVE_API),
    (TOXICITY, REWIRE),
    (TOXICITY, HATEROBERTA),
    (TOXICITY, GPT4),
]

def run_experiments(dataset_type):
    download_dataset(SOCIAL_ACCEPTABILITY, dataset_type=dataset_type)
    download_dataset(TOXICITY, dataset_type=dataset_type)

    for task, dataset_or_model in experiments:
        print(task, dataset_or_model)
        df = get_pearson_rs(task, dataset_or_model, dataset_type=dataset_type)
        print(df)
        df.to_csv(f"{task}_{dataset_or_model}_{dataset_type}_output.csv")

if __name__ == "__main__":
    dataset_type = "processed" # raw
    run_experiments(dataset_type)
# Out:
# social-acceptability socialchem
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic        0.47    0.001540418524465035
# 1                country_longest_Baltic       0.71*   3.201776412603727e-06
# 2       country_longest_Catholic-Europe       0.69*  1.2364417073492533e-12
# 3             country_longest_Confucian       0.69*   7.240293317491829e-13
# 4      country_longest_English-Speaking       0.77*   3.525689592550772e-57
# 5         country_longest_Latin-America        0.46    0.015292280809731922
# 6       country_longest_Orthodox-Europe       0.58*   1.504066046426162e-07
# 7     country_longest_Protestant-Europe       0.65*  1.2880308352451281e-17
# 8       country_longest_West-South-Asia       0.63*  1.6313552299896291e-09
# 9                     education_college       0.73*  1.0695570799912059e-48
# 10            education_graduate school       0.73*  1.1543924941578026e-46
# 11                education_high school       0.68*   7.888561031036138e-39
# 12                        education_phd       0.64*  2.9965839129353884e-28
# 13            education_pre-high school       0.56*    4.47723010385647e-17
# 14        education_professional school       0.53*  2.1902946060297556e-13
# 15                      ethnicity_asian       0.66*   4.853051957339568e-35
# 16                      ethnicity_black       0.61*  3.5046805530315906e-24
# 17              ethnicity_latino/latina       0.62*   5.182292995495345e-21
# 18            ethnicity_native american       0.59*  2.3312456745101543e-07
# 19           ethnicity_pacific islander       0.65*   0.0006627076748404865
# 20                      ethnicity_white       0.74*   3.007044458597469e-49
# 21                           gender_man       0.74*  1.1730843036089546e-49
# 22                    gender_non-binary       0.60*   7.987977739359908e-27
# 23                         gender_woman       0.76*  1.0490786115085988e-53
# 24              native_language_english       0.78*   3.513206485125259e-58
# 25          native_language_not english       0.64*  3.2844945688160457e-28
# 26                            age_10-20       0.69*  1.4586328655720815e-40
# 27                            age_20-30       0.73*   6.660993989076901e-49
# 28                            age_30-40       0.68*  1.8745210854332967e-35
# 29                            age_40-50       0.62*   2.788155231688273e-24
# 30                            age_50-60       0.66*  2.2551609827490628e-21
# 31                            age_60-70       0.58*   6.910066109554817e-15
# 32                            age_70-80       0.56*   5.139000573263512e-05
# 33                             age_> 80        0.52     0.47531756287909566
# 34    country_residence_African-Islamic        0.40     0.06376432386226501
# 35             country_residence_Baltic       0.68*   6.233150659767815e-07
# 36    country_residence_Catholic-Europe       0.57*  3.2129705330558103e-10
# 37          country_residence_Confucian       0.69*   3.950240859271671e-13
# 38   country_residence_English-Speaking       0.77*   7.554274955595594e-56
# 39      country_residence_Latin-America       0.55*   5.292981231947238e-05
# 40    country_residence_Orthodox-Europe       0.52*  0.00014520718429652808
# 41  country_residence_Protestant-Europe       0.63*   2.192771495032914e-19
# 42    country_residence_West-South-Asia       0.61*   3.462636571208208e-08
# 43                    religion_buddhist       0.64*   7.415040415664196e-13
# 44                   religion_christian       0.74*  1.7370387407453087e-49
# 45                       religion_hindu       0.65*   4.617641162975282e-14
# 46                         religion_jew       0.66*   8.321681251249575e-17
# 47                      religion_muslim       0.62*  2.3052063837670045e-16
# 48                   religion_spiritual       0.61*   9.752487006218257e-08
# social-acceptability delphi
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic        0.40    0.028997447301207825
# 1                country_longest_Baltic       0.71*   2.491788922170993e-06
# 2       country_longest_Catholic-Europe       0.58*   7.480531129358734e-08
# 3             country_longest_Confucian       0.53*   2.294002923069087e-06
# 4      country_longest_English-Speaking       0.63*   2.227519543201316e-31
# 5         country_longest_Latin-America        0.42     0.05766575501890948
# 6       country_longest_Orthodox-Europe       0.60*   4.189671810007147e-08
# 7     country_longest_Protestant-Europe       0.51*  3.3302694926759284e-09
# 8       country_longest_West-South-Asia       0.60*  2.1038726120483283e-08
# 9                     education_college       0.64*  1.0508727985716667e-32
# 10            education_graduate school       0.56*  3.1535391268194524e-23
# 11                education_high school       0.54*  1.6473187366676058e-21
# 12                        education_phd       0.51*  2.2677354679534826e-16
# 13            education_pre-high school       0.46*    8.52643669567168e-11
# 14        education_professional school       0.46*   1.503646862712931e-09
# 15                      ethnicity_asian       0.55*  1.4825920691174656e-22
# 16                      ethnicity_black       0.50*    8.08040835176939e-15
# 17              ethnicity_latino/latina       0.53*  5.0683181381313987e-14
# 18            ethnicity_native american       0.52*  3.1113518268572025e-05
# 19           ethnicity_pacific islander        0.63   0.0013822378217105402
# 20                      ethnicity_white       0.61*  1.4368921185489549e-29
# 21                           gender_man       0.62*  3.0346457437899823e-31
# 22                    gender_non-binary       0.52*  1.9890684533593162e-18
# 23                         gender_woman       0.59*   2.237757362256586e-27
# 24              native_language_english       0.64*   6.504980557409265e-33
# 25          native_language_not english       0.52*   3.595499685043851e-17
# 26                            age_10-20       0.60*  6.8186894429749345e-28
# 27                            age_20-30       0.66*  1.2802450030455142e-36
# 28                            age_30-40       0.51*   3.387375291719269e-17
# 29                            age_40-50       0.54*  1.2899468197329967e-17
# 30                            age_50-60       0.52*   1.709689397253171e-11
# 31                            age_60-70       0.44*  1.1043361245815085e-07
# 32                            age_70-80       0.52*  0.00041991353866038485
# 33                             age_> 80        0.48      0.9082920493897769
# 34    country_residence_African-Islamic        0.40    0.058574285897946235
# 35             country_residence_Baltic       0.59*  0.00014740628940478406
# 36    country_residence_Catholic-Europe       0.42*    6.74686939549928e-05
# 37          country_residence_Confucian       0.62*  1.9077791096616907e-09
# 38   country_residence_English-Speaking       0.65*     1.8427157478037e-34
# 39      country_residence_Latin-America       0.57*  2.4791289142824115e-05
# 40    country_residence_Orthodox-Europe       0.60*  1.7295033976561558e-06
# 41  country_residence_Protestant-Europe       0.52*  6.4478929282707565e-12
# 42    country_residence_West-South-Asia       0.57*   8.914728889704826e-07
# 43                    religion_buddhist       0.58*   3.164738787469253e-10
# 44                   religion_christian       0.54*  2.1531650675188297e-21
# 45                       religion_hindu       0.60*   3.572202026829469e-11
# 46                         religion_jew       0.60*  1.8538285380460558e-13
# 47                      religion_muslim       0.60*  1.9617004094725924e-14
# 48                   religion_spiritual       0.60*   3.486401028748617e-07
# social-acceptability gpt4
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic        0.46    0.002109722529348019
# 1                country_longest_Baltic       0.69*  1.2803182149092487e-05
# 2       country_longest_Catholic-Europe       0.73*   5.254150152205084e-15
# 3             country_longest_Confucian       0.70*   2.105230939838126e-13
# 4      country_longest_English-Speaking       0.72*   3.635377365858061e-46
# 5         country_longest_Latin-America        0.48    0.008597972344758871
# 6       country_longest_Orthodox-Europe       0.67*  3.2636274223305753e-11
# 7     country_longest_Protestant-Europe       0.67*   4.900234217026569e-19
# 8       country_longest_West-South-Asia       0.59*   4.528496725770635e-08
# 9                     education_college       0.70*  1.2686799788795282e-41
# 10            education_graduate school       0.67*   4.067942556308434e-37
# 11                education_high school       0.67*  1.0458368318192188e-36
# 12                        education_phd       0.64*    2.10791458902562e-28
# 13            education_pre-high school       0.59*   7.001726142182724e-20
# 14        education_professional school       0.49*   3.501438588722219e-11
# 15                      ethnicity_asian       0.62*   8.400773710573792e-31
# 16                      ethnicity_black       0.57*  2.0288947882780897e-20
# 17              ethnicity_latino/latina       0.52*   8.017965066060913e-14
# 18            ethnicity_native american       0.64*  3.4403850069368276e-09
# 19           ethnicity_pacific islander        0.62   0.0022180842430188285
# 20                      ethnicity_white       0.70*  2.1047745417722503e-42
# 21                           gender_man       0.71*  3.3549472608150265e-44
# 22                    gender_non-binary       0.56*   3.487090829998309e-22
# 23                         gender_woman       0.75*  3.5166014049309186e-51
# 24              native_language_english       0.72*   4.424678227680545e-46
# 25          native_language_not english       0.66*  2.0972112211764165e-30
# 26                            age_10-20       0.69*   7.374357367303039e-41
# 27                            age_20-30       0.70*  1.0694322881765934e-41
# 28                            age_30-40       0.62*  2.4537669452818177e-28
# 29                            age_40-50       0.64*   9.269328163749628e-27
# 30                            age_50-60       0.58*  2.5373443939882314e-15
# 31                            age_60-70       0.52*   3.017064833877927e-11
# 32                            age_70-80       0.56*  3.9093344996623825e-05
# 33                             age_> 80        0.60     0.08631074218969954
# 34    country_residence_African-Islamic        0.45    0.009949717783367616
# 35             country_residence_Baltic        0.48    0.012265960846126026
# 36    country_residence_Catholic-Europe       0.66*   3.048804787033788e-15
# 37          country_residence_Confucian       0.72*   2.681325331170412e-14
# 38   country_residence_English-Speaking       0.73*   1.412774551140997e-48
# 39      country_residence_Latin-America       0.60*  3.6091443567872717e-06
# 40    country_residence_Orthodox-Europe       0.60*   1.382461265552124e-06
# 41  country_residence_Protestant-Europe       0.62*   6.734634426992453e-19
# 42    country_residence_West-South-Asia       0.53*  1.2904523252874359e-05
# 43                    religion_buddhist       0.55*   7.779889369079211e-09
# 44                   religion_christian       0.72*  1.2279910186616405e-46
# 45                       religion_hindu       0.58*  2.9698689569537284e-10
# 46                         religion_jew       0.60*   4.972543175991917e-13
# 47                      religion_muslim       0.68*  2.5049759417348677e-20
# 48                   religion_spiritual       0.72*   3.562843258288739e-12
# toxicity dynahate
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic       0.40*  0.00023565453240915107
# 1                country_longest_Baltic        0.32                     1.0
# 2       country_longest_Catholic-Europe        0.39   0.0016048583278629412
# 3             country_longest_Confucian       0.50*  0.00010656021318652904
# 4      country_longest_English-Speaking       0.70*  1.5149525270799115e-43
# 5         country_longest_Latin-America        0.41      0.2689937013802478
# 6       country_longest_Orthodox-Europe        0.35      0.1221862789334822
# 7     country_longest_Protestant-Europe       0.49*  2.2503362249928076e-09
# 8       country_longest_West-South-Asia        0.35     0.13834316496486138
# 9                     education_college       0.67*   6.157198790415424e-38
# 10            education_graduate school       0.59*  1.6502246496928204e-24
# 11                education_high school       0.60*   9.488343224619098e-27
# 12                        education_phd       0.51*  3.6715787971544543e-13
# 13            education_pre-high school        0.36    0.015683113041565843
# 14        education_professional school       0.59*  3.3862695759655967e-13
# 15                      ethnicity_asian       0.58*   9.451987191578038e-24
# 16                      ethnicity_black       0.51*    2.21895861111797e-12
# 17              ethnicity_latino/latina       0.44*  1.5593430593805513e-08
# 18            ethnicity_native american        0.14                     1.0
# 19           ethnicity_pacific islander        0.25                     1.0
# 20                      ethnicity_white       0.71*  1.8860256589882368e-45
# 21                           gender_man       0.66*  3.1675311563485624e-36
# 22                    gender_non-binary       0.59*  1.5765056592880347e-18
# 23                         gender_woman       0.67*   9.155267999900084e-39
# 24              native_language_english       0.71*  1.3732002740224146e-45
# 25          native_language_not english       0.52*   4.843486883868615e-16
# 26                            age_10-20       0.63*   5.655535373487373e-33
# 27                            age_20-30       0.66*  1.3541902515006574e-36
# 28                            age_30-40       0.49*   2.951033460695635e-13
# 29                            age_40-50       0.65*   5.254827063243401e-21
# 30                            age_50-60       0.53*  1.2295796824171726e-11
# 31                            age_60-70        0.41                     1.0
# 32                            age_70-80        0.49                     1.0
# 33                             age_> 80        0.63                     1.0
# 34    country_residence_African-Islamic        0.34    0.015657495129196036
# 35             country_residence_Baltic        0.44                     1.0
# 36    country_residence_Catholic-Europe        0.38   0.0032724173818653906
# 37          country_residence_Confucian       0.56*   5.450967895978991e-06
# 38   country_residence_English-Speaking       0.70*  4.2373969861782685e-44
# 39      country_residence_Latin-America        0.30                     1.0
# 40    country_residence_Orthodox-Europe        0.25                     1.0
# 41  country_residence_Protestant-Europe       0.51*   1.018660534081996e-10
# 42    country_residence_West-South-Asia        0.62    0.034993158317658056
# 43                    religion_buddhist        0.48    0.004190269897526801
# 44                   religion_christian       0.53*   2.667757945897611e-20
# 45                       religion_hindu       0.50*   6.679691253229185e-06
# 46                         religion_jew       0.70*  1.9485131679379492e-16
# 47                      religion_muslim        0.47    0.004412920276016215
# 48                   religion_spiritual        0.47      0.8152241579152031
# toxicity perspective
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic        0.26     0.16090276293587608
# 1                country_longest_Baltic        0.10                     1.0
# 2       country_longest_Catholic-Europe        0.11                     1.0
# 3             country_longest_Confucian        0.24                     1.0
# 4      country_longest_English-Speaking       0.36*  1.2459549200589764e-08
# 5         country_longest_Latin-America        0.18                     1.0
# 6       country_longest_Orthodox-Europe        0.20                     1.0
# 7     country_longest_Protestant-Europe       0.37*    7.39491326934536e-05
# 8       country_longest_West-South-Asia        0.23                     1.0
# 9                     education_college       0.34*   5.304064787022954e-08
# 10            education_graduate school       0.31*  1.5996804240445193e-05
# 11                education_high school       0.34*    3.17044401177213e-07
# 12                        education_phd        0.27    0.003802720907776638
# 13            education_pre-high school        0.19                     1.0
# 14        education_professional school        0.05                     1.0
# 15                      ethnicity_asian       0.38*     8.1687485763961e-09
# 16                      ethnicity_black        0.27     0.00852660909001382
# 17              ethnicity_latino/latina        0.30   0.0015665429070816782
# 18            ethnicity_native american        0.27                     1.0
# 19           ethnicity_pacific islander        0.55     0.00472101325564757
# 20                      ethnicity_white       0.33*  1.5394533501894034e-07
# 21                           gender_man       0.35*    4.37346760874663e-08
# 22                    gender_non-binary        0.19     0.27765215976085783
# 23                         gender_woman       0.37*   2.987519923981173e-09
# 24              native_language_english       0.35*  3.9407311512542535e-08
# 25          native_language_not english       0.40*   1.689371829724941e-08
# 26                            age_10-20       0.37*  2.9698691955380446e-09
# 27                            age_20-30       0.35*   1.740940830756988e-08
# 28                            age_30-40       0.28*   0.0008884204122227936
# 29                            age_40-50        0.29    0.003677816897612779
# 30                            age_50-60       0.35*    0.000294907087511851
# 31                            age_60-70        0.39                     1.0
# 32                            age_70-80        0.36                     1.0
# 33                             age_> 80        0.01                     1.0
# 34    country_residence_African-Islamic        0.14                     1.0
# 35             country_residence_Baltic        0.20                     1.0
# 36    country_residence_Catholic-Europe        0.15                     1.0
# 37          country_residence_Confucian        0.35     0.10631477176182043
# 38   country_residence_English-Speaking       0.36*   4.733329282285711e-09
# 39      country_residence_Latin-America        0.12                     1.0
# 40    country_residence_Orthodox-Europe        0.29                     1.0
# 41  country_residence_Protestant-Europe        0.32   0.0013188920274257844
# 42    country_residence_West-South-Asia        0.18                     1.0
# 43                    religion_buddhist        0.18                     1.0
# 44                   religion_christian       0.37*   9.009919426485772e-09
# 45                       religion_hindu        0.29     0.16615138838269278
# 46                         religion_jew        0.31     0.03314260345096104
# 47                      religion_muslim        0.22                     1.0
# 48                   religion_spiritual       -0.12                     1.0
# toxicity rewire
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic       0.43*   4.457608319517876e-05
# 1                country_longest_Baltic        0.37         0.7503604233516
# 2       country_longest_Catholic-Europe        0.34     0.01918106042848204
# 3             country_longest_Confucian        0.44   0.0019943317880251146
# 4      country_longest_English-Speaking       0.60*  2.2650399115967483e-29
# 5         country_longest_Latin-America        0.35                     1.0
# 6       country_longest_Orthodox-Europe        0.38     0.03897296695831993
# 7     country_longest_Protestant-Europe       0.38*   4.222761751517143e-05
# 8       country_longest_West-South-Asia        0.37     0.07420891213636895
# 9                     education_college       0.58*     5.0611634989215e-26
# 10            education_graduate school       0.53*   2.922152430078279e-18
# 11                education_high school       0.54*   3.326434957125334e-20
# 12                        education_phd       0.46*   3.495025695457085e-10
# 13            education_pre-high school        0.40   0.0036623328584104923
# 14        education_professional school       0.36*   0.0006738300807163555
# 15                      ethnicity_asian       0.49*   6.015178198563388e-16
# 16                      ethnicity_black       0.33*  0.00022762880134926237
# 17              ethnicity_latino/latina       0.44*   1.399554396956473e-08
# 18            ethnicity_native american        0.26                     1.0
# 19           ethnicity_pacific islander        0.50     0.02623425451060759
# 20                      ethnicity_white       0.60*   9.029816361709278e-29
# 21                           gender_man       0.61*  2.1936191281722447e-30
# 22                    gender_non-binary       0.37*  1.5897155554149187e-06
# 23                         gender_woman       0.56*   9.352510509578164e-25
# 24              native_language_english       0.61*   8.812201008116936e-30
# 25          native_language_not english       0.50*  3.5681652392703306e-14
# 26                            age_10-20       0.59*  1.0854988113974227e-27
# 27                            age_20-30       0.56*   3.165685090116234e-24
# 28                            age_30-40       0.43*   5.569099919511782e-10
# 29                            age_40-50       0.57*   4.773349948654478e-15
# 30                            age_50-60       0.46*  3.6161307491566244e-08
# 31                            age_60-70        0.45      0.5214024556343784
# 32                            age_70-80        0.35                     1.0
# 33                             age_> 80        0.45                     1.0
# 34    country_residence_African-Islamic        0.23      0.7424552642651975
# 35             country_residence_Baltic        0.66     0.07749172350751211
# 36    country_residence_Catholic-Europe       0.45*  0.00011233755205239687
# 37          country_residence_Confucian       0.53*   5.215016398387878e-05
# 38   country_residence_English-Speaking       0.62*   6.508190502121079e-31
# 39      country_residence_Latin-America        0.26                     1.0
# 40    country_residence_Orthodox-Europe        0.29                     1.0
# 41  country_residence_Protestant-Europe       0.36*   0.0001373889773419366
# 42    country_residence_West-South-Asia        0.53     0.25560040442958337
# 43                    religion_buddhist        0.22                     1.0
# 44                   religion_christian       0.49*   1.431678110987366e-16
# 45                       religion_hindu        0.36    0.009593436928137154
# 46                         religion_jew       0.48*  2.7838643569839745e-06
# 47                      religion_muslim        0.36     0.18855252587849705
# 48                   religion_spiritual        0.38                     1.0
# toxicity hateroberta
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic        0.32    0.015197574625558784
# 1                country_longest_Baltic       -0.03                     1.0
# 2       country_longest_Catholic-Europe        0.18                     1.0
# 3             country_longest_Confucian        0.20                     1.0
# 4      country_longest_English-Speaking       0.38*   6.061908374432264e-10
# 5         country_longest_Latin-America        0.17                     1.0
# 6       country_longest_Orthodox-Europe        0.12                     1.0
# 7     country_longest_Protestant-Europe       0.39*  1.3542357826517967e-05
# 8       country_longest_West-South-Asia        0.37     0.08019386906455923
# 9                     education_college       0.39*   8.386064077777641e-11
# 10            education_graduate school       0.32*   6.021513820648833e-06
# 11                education_high school       0.35*  1.8387661928619477e-07
# 12                        education_phd        0.28   0.0032872367128266144
# 13            education_pre-high school        0.18                     1.0
# 14        education_professional school        0.08                     1.0
# 15                      ethnicity_asian       0.34*   4.277726821340587e-07
# 16                      ethnicity_black        0.29   0.0026610152892359395
# 17              ethnicity_latino/latina        0.25     0.02586795515732316
# 18            ethnicity_native american        0.28      0.9381621332965361
# 19           ethnicity_pacific islander        0.46      0.0743933565309381
# 20                      ethnicity_white       0.36*  1.2389241579104826e-08
# 21                           gender_man       0.35*  3.9483948969579915e-08
# 22                    gender_non-binary        0.25    0.012417581676978384
# 23                         gender_woman       0.38*   6.087305757796436e-10
# 24              native_language_english       0.39*  2.2756179535410542e-10
# 25          native_language_not english       0.42*  1.0036423811483015e-09
# 26                            age_10-20       0.39*  1.2112224654244874e-10
# 27                            age_20-30       0.37*   4.384036940895553e-09
# 28                            age_30-40       0.32*  3.1000929871295314e-05
# 29                            age_40-50        0.29    0.005432517647160113
# 30                            age_50-60        0.31   0.0035195613219232025
# 31                            age_60-70        0.14                     1.0
# 32                            age_70-80        0.25                     1.0
# 33                             age_> 80       -0.09                     1.0
# 34    country_residence_African-Islamic        0.16                     1.0
# 35             country_residence_Baltic        0.23                     1.0
# 36    country_residence_Catholic-Europe        0.20                     1.0
# 37          country_residence_Confucian        0.46   0.0014204677604269555
# 38   country_residence_English-Speaking       0.40*   4.918799804113911e-11
# 39      country_residence_Latin-America       -0.04                     1.0
# 40    country_residence_Orthodox-Europe        0.23                     1.0
# 41  country_residence_Protestant-Europe        0.32   0.0013577978813778782
# 42    country_residence_West-South-Asia        0.09                     1.0
# 43                    religion_buddhist        0.16                     1.0
# 44                   religion_christian       0.35*   4.372896786369006e-08
# 45                       religion_hindu        0.31     0.09296293663335334
# 46                         religion_jew        0.28     0.11201072144864581
# 47                      religion_muslim        0.18                     1.0
# 48                   religion_spiritual        0.26                     1.0
# toxicity gpt4
#                             demographic pearson's r                 p-value
# 0       country_longest_African-Islamic        0.25     0.25499448718180395
# 1                country_longest_Baltic        0.12                     1.0
# 2       country_longest_Catholic-Europe        0.18                     1.0
# 3             country_longest_Confucian        0.42    0.004073459667465636
# 4      country_longest_English-Speaking       0.43*   6.968410831237647e-13
# 5         country_longest_Latin-America        0.28                     1.0
# 6       country_longest_Orthodox-Europe        0.18                     1.0
# 7     country_longest_Protestant-Europe       0.37*  5.9656443648995084e-05
# 8       country_longest_West-South-Asia        0.33     0.25504443977087604
# 9                     education_college       0.40*   5.280807163366847e-11
# 10            education_graduate school       0.40*   7.739015541567767e-10
# 11                education_high school       0.36*   4.327756281057414e-08
# 12                        education_phd       0.40*   2.519706907982855e-07
# 13            education_pre-high school        0.33     0.05535906364056561
# 14        education_professional school        0.20      0.8514217504686228
# 15                      ethnicity_asian       0.38*   8.681098580923179e-09
# 16                      ethnicity_black       0.35*   4.741183939149243e-05
# 17              ethnicity_latino/latina        0.29    0.003529487208627491
# 18            ethnicity_native american        0.28      0.9889039958011412
# 19           ethnicity_pacific islander        0.53    0.009420301905154709
# 20                      ethnicity_white       0.40*   1.909354356148193e-11
# 21                           gender_man       0.37*   4.101612047061128e-09
# 22                    gender_non-binary       0.33*   7.652234488587149e-05
# 23                         gender_woman       0.37*  1.0061245032944393e-09
# 24              native_language_english       0.43*  1.8217565921148673e-13
# 25          native_language_not english       0.44*   9.450286418501883e-11
# 26                            age_10-20       0.34*   7.938415265180104e-08
# 27                            age_20-30       0.43*  4.0211563202832754e-13
# 28                            age_30-40       0.36*  1.7901178248291526e-06
# 29                            age_40-50       0.35*   9.809386743656452e-05
# 30                            age_50-60        0.26    0.037915591520871615
# 31                            age_60-70        0.14                     1.0
# 32                            age_70-80       0.85*   6.156159481105827e-05
# 33                             age_> 80        0.43                     1.0
# 34    country_residence_African-Islamic        0.26      0.3160375611644199
# 35             country_residence_Baltic        0.20                     1.0
# 36    country_residence_Catholic-Europe        0.24      0.7104005548327246
# 37          country_residence_Confucian        0.42    0.007014116222999374
# 38   country_residence_English-Speaking       0.43*   3.770064952907478e-13
# 39      country_residence_Latin-America        0.17                     1.0
# 40    country_residence_Orthodox-Europe        0.23                     1.0
# 41  country_residence_Protestant-Europe       0.33*   0.0005922819632465146
# 42    country_residence_West-South-Asia        0.19                     1.0
# 43                    religion_buddhist        0.38      0.1417086574222684
# 44                   religion_christian       0.35*   5.479930131337894e-08
# 45                       religion_hindu        0.35    0.015624603495435159
# 46                         religion_jew        0.28     0.09862809899368166
# 47                      religion_muslim        0.25                     1.0
# 48                   religion_spiritual        nan0                     nan
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
